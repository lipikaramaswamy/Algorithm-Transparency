# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
rawdf = pd.read_csv('data/compas-scores-raw.csv')

# %%
print('size of df: ', rawdf.shape)
rawdf.head()
# Out:
# size of df:  (60843, 28)
#    Person_ID  AssessmentID  Case_ID Agency_Text LastName FirstName MiddleName  \
# 0      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 1      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 2      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 3      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 4      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
#
#   Sex_Code_Text Ethnic_Code_Text DateOfBirth  ScaleSet_ID            ScaleSet  \
# 0          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 1          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 2          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 3          Male        Caucasian    09/16/84           22  Risk and Prescreen
# 4          Male        Caucasian    09/16/84           22  Risk and Prescreen
#
# ...

# %%
# rawdf['Screening_Date'] = pd.to_datetime(rawdf['Screening_Date'])
# rawdf['DateOfBirth'] = pd.to_datetime(rawdf['DateOfBirth'])

# new col for age at arrest
rawdf['AgeAtArrest'] = (rawdf['Screening_Date'] - rawdf['DateOfBirth'])

rawdf['AgeAtArrest'] = rawdf['AgeAtArrest'].apply(lambda x: x.days)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-ca0df68ffd99> in <module>
#       3
#       4 # new col for age at arrest
# ----> 5 rawdf['AgeAtArrest'] = (rawdf['Screening_Date'] - rawdf['DateOfBirth']).days
#
# /anaconda3/envs/109b/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'days'

# %%
type(rawdf.AgeAtArrest[0])
# Out:
# pandas._libs.tslibs.timedeltas.Timedelta

# %%
rawdf.head()
# Out:
#    Person_ID  AssessmentID  Case_ID Agency_Text LastName FirstName MiddleName  \
# 0      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 1      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 2      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 3      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 4      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
#
#   Sex_Code_Text Ethnic_Code_Text DateOfBirth  ScaleSet_ID            ScaleSet  \
# 0          Male        Caucasian  1992-12-05           22  Risk and Prescreen
# 1          Male        Caucasian  1992-12-05           22  Risk and Prescreen
# 2          Male        Caucasian  1992-12-05           22  Risk and Prescreen
# 3          Male        Caucasian  1984-09-16           22  Risk and Prescreen
# 4          Male        Caucasian  1984-09-16           22  Risk and Prescreen
#
# ...

# %%
unique_person_check = rawdf.groupby('Person_ID').aggregate({'AssessmentID' : 'count'}).reset_index()

# %%
unique_person_check[unique_person_check.AssessmentID > 3].count()
# Out:
# Person_ID       1533
# AssessmentID    1533
# dtype: int64
